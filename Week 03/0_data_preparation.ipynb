# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in c:\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 1)) (2.3.5)
# Requirement already satisfied: pandas in c:\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: scikit-learn in c:\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 3)) (1.7.2)
# Requirement already satisfied: imbalanced-learn in c:\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: matplotlib in c:\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 5)) (3.10.7)
# Requirement already satisfied: seaborn in c:\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: plotly in c:\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 7)) (6.5.0)
# Requirement already satisfied: joblib in c:\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 8)) (1.5.2)
# Requirement already satisfied: pyyaml in c:\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 9)) (6.0.3)
# Requirement already satisfied: python-dotenv in c:\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 10)) (1.2.1)
# Requirement already satisfied: pandas-profiling in c:\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: statsmodels in c:\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 12)) (0.14.6)
# Requirement already satisfied: ipython in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 13)) (9.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\envs\bprmls\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda3\envs\bprmls\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\anaconda3\envs\bprmls\lib\site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\anaconda3\envs\bprmls\lib\site-packages (from scikit-learn->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from matplotlib->-r requirements.txt (line 5)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in c:\anaconda3\envs\bprmls\lib\site-packages (from plotly->-r requirements.txt (line 7)) (2.14.0)
# Requirement already satisfied: pydantic>=1.8.1 in c:\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (2.12.5)
# Requirement already satisfied: jinja2>=2.11.1 in c:\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (3.1.6)
# Requirement already satisfied: visions==0.7.1 in c:\anaconda3\envs\bprmls\lib\site-packages (from visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (0.12.5)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in c:\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (0.1.0)
# Requirement already satisfied: requests>=2.24.0 in c:\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (2.32.5)
# Requirement already satisfied: tqdm>=4.48.2 in c:\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (4.67.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\anaconda3\envs\bprmls\lib\site-packages (from visions==0.7.1->visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\anaconda3\envs\bprmls\lib\site-packages (from visions==0.7.1->visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (3.6.1)
# Requirement already satisfied: bottleneck in c:\anaconda3\envs\bprmls\lib\site-packages (from visions==0.7.1->visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (1.6.0)
# Requirement already satisfied: multimethod==1.4 in c:\anaconda3\envs\bprmls\lib\site-packages (from visions==0.7.1->visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (1.4)
# Requirement already satisfied: imagehash in c:\anaconda3\envs\bprmls\lib\site-packages (from visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (4.3.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\anaconda3\envs\bprmls\lib\site-packages (from statsmodels->-r requirements.txt (line 12)) (1.0.2)
# Requirement already satisfied: colorama in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from ipython->-r requirements.txt (line 13)) (0.4.6)
# Requirement already satisfied: decorator in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from ipython->-r requirements.txt (line 13)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from ipython->-r requirements.txt (line 13)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from ipython->-r requirements.txt (line 13)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from ipython->-r requirements.txt (line 13)) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from ipython->-r requirements.txt (line 13)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from ipython->-r requirements.txt (line 13)) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from ipython->-r requirements.txt (line 13)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from ipython->-r requirements.txt (line 13)) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\anaconda3\envs\bprmls\lib\site-packages (from ipython->-r requirements.txt (line 13)) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->-r requirements.txt (line 13)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 13)) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\envs\bprmls\lib\site-packages (from jinja2>=2.11.1->pandas-profiling->-r requirements.txt (line 11)) (3.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\anaconda3\envs\bprmls\lib\site-packages (from pydantic>=1.8.1->pandas-profiling->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\anaconda3\envs\bprmls\lib\site-packages (from pydantic>=1.8.1->pandas-profiling->-r requirements.txt (line 11)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\anaconda3\envs\bprmls\lib\site-packages (from pydantic>=1.8.1->pandas-profiling->-r requirements.txt (line 11)) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\envs\bprmls\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda3\envs\bprmls\lib\site-packages (from requests>=2.24.0->pandas-profiling->-r requirements.txt (line 11)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\envs\bprmls\lib\site-packages (from requests>=2.24.0->pandas-profiling->-r requirements.txt (line 11)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda3\envs\bprmls\lib\site-packages (from requests>=2.24.0->pandas-profiling->-r requirements.txt (line 11)) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\envs\bprmls\lib\site-packages (from requests>=2.24.0->pandas-profiling->-r requirements.txt (line 11)) (2025.11.12)
# Requirement already satisfied: PyWavelets in c:\anaconda3\envs\bprmls\lib\site-packages (from imagehash->visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (1.9.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from stack_data->ipython->-r requirements.txt (line 13)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from stack_data->ipython->-r requirements.txt (line 13)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\dunith munasinghe\appdata\roaming\python\python311\site-packages (from stack_data->ipython->-r requirements.txt (line 13)) (0.2.3)

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer 
from imblearn.over_sampling import SMOTE
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder

# %% [markdown]
# # 1. Loading and Exploring Data

# %%
df = pd.read_csv('data/processed/ChurnModelling_Binning_Applied.csv')
df.head()
# Out:
#   Geography  Gender      Age  ...  EstimatedSalary  Exited  CreditScoreBins
# 0    France  Female  3.76120  ...        101348.88       1             Fair
# 1     Spain  Female  3.73767  ...        112542.58       0             Fair
# 2    France  Female  3.76120  ...        113931.57       1             Poor
# 3    France  Female  3.68668  ...         93826.63       0             Good
# 4     Spain  Female  3.78419  ...         79084.10       0        Excellent
#
# [5 rows x 11 columns]

# %% [markdown]
# # 2. Building Scikit-Learn Pipeline

# %%
remainder_features = ['NumOfProducts', 'HasCrCard', 'IsActiveMember', 'Exited']
numerical_features = ['Age', 'Tenure', 'Balance', 'EstimatedSalary']
nominal_features = ['Gender', 'Geography']
ordinal_features = ['CreditScoreBins']

numerical_transformer = Pipeline(
                                steps=[
                                    ('imputer', SimpleImputer(strategy='median')),
                                    ('scaler', StandardScaler())
                                ]
                                )

norminal_transformer = Pipeline(
                                steps=[
                                    ('imputer', SimpleImputer(
                                                            strategy='constant',
                                                            fill_value='missing'
                                                            )),
                                    ('encoder', OneHotEncoder())
                                ]
                                )

ordinal_transformer = Pipeline(
                                steps=[
                                    ('imputer', SimpleImputer(
                                                            strategy='constant',
                                                            fill_value='missing'
                                                            )),
                                    ('encoder', OrdinalEncoder())
                                ]
                                )

preprocessor = ColumnTransformer(
                                transformers=[
                                            ('num', numerical_transformer, numerical_features),
                                            ('nom', norminal_transformer, nominal_features),
                                            ('ord', ordinal_transformer, ordinal_features)
                                ],
                                remainder='drop'
                                )

norminal_feature_names = []
for feature in nominal_features:
    unique_values = df[feature].unique()
    norminal_feature_names.extend([f"{feature}_{val}" for val in unique_values])

df_cp = df.copy()
df_transformed = pd.DataFrame(
                            preprocessor.fit_transform(df_cp),
                            columns=numerical_features+norminal_feature_names+ordinal_features
                            )
df_remainder = df[remainder_features]
df_pp = pd.concat(
                [df_transformed, df_remainder], 
                axis=1
                )
